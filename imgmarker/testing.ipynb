# %%
import PIL.Image as pillow
from PIL.TiffTags import TAGS
import matplotlib
from matplotlib import pyplot as plt

# %%
image_path = "/home/astrorya/Desktop/Research/Research/Lindsey-Bleem/imgmarker/imgmarker/tests/test_images/important_test_image.jpg"
with pillow.open(image_path) as f:
    plt.imshow(f)
